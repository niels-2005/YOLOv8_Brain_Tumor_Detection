# %%
from helper import *

# %%
# plot evaluation metrics

df = get_results_df(plot_confusion_matrix=False)

# %%
# load best model from Training
best_model = get_best_model()

# %%
# predict random samples (validation set) with best finetuned model

predict_random_samples(
    model=best_model,
    img_path=CFG.img_valid_path,
    plot_title="Best Model Brain Tumor Predictions",
)
# Out:
# image 1/1 /home/ubuntu/dev/yolo-tumor/dataset/brain-tumor/valid/images/val_1 (75).jpg: 640x640 1 negative, 4.0ms
# Speed: 5.9ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/ubuntu/dev/yolo-tumor/dataset/brain-tumor/valid/images/val_1 (41).jpg: 640x640 1 negative, 1 positive, 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/ubuntu/dev/yolo-tumor/dataset/brain-tumor/valid/images/val_1 (222).jpg: 640x640 1 negative, 3.5ms
# Speed: 1.4ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/ubuntu/dev/yolo-tumor/dataset/brain-tumor/valid/images/val_1 (68).jpg: 640x640 1 negative, 3.9ms
# Speed: 1.5ms preprocess, 3.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/ubuntu/dev/yolo-tumor/dataset/brain-tumor/valid/images/val_1 (45).jpg: 640x640 1 negative, 3.7ms
# ...
